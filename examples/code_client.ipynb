# %%
from moncenterlib.gnss.code_client import CODEClient

cod = CODEClient()
path = "/output_dir"

# %%
dates = {"start": "2025-11-30", "end": "2026-02-01"}
cod.download(dates, "SP3", path)

# %%
dates = ["2025-11-30", "2025-12-12", "2026-01-07", "2026-02-22"]
cod.download(dates, "CLK", path)

# %%
dates = ["2025-11-30", "2025-12-12", "2026-01-07", "2026-02-22"]

for t in ["ION", "ERP", "SP3", "CLK", "CLK_05S", "DCB_P1C1", "DCB_P1P2"]:
    cod.download(dates, t, path)
